# %% [markdown]
# # Домашня робота №4

# %% [markdown]
# # Дискретні розподіли

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 Від'ємний біноміальний розподіл

# %% [markdown]
# Більш детальна інформація в [документації](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.nbinom.html).

# %%
from scipy.stats import nbinom

# %%
n = 5
p = 0.4

# %% [markdown]
# ### 1.1 Щільність

# %%
x = np.arange(-0.5, n*5+1, 0.5)

# %% [markdown]
# Виведіть значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
# Місце для Вашого коду

nbinom.pmf(x, n, p)
# Out:
# array([0.        , 0.01024   , 0.        , 0.03072   , 0.        ,
#        0.055296  , 0.        , 0.0774144 , 0.        , 0.09289728,
#        0.        , 0.10032906, 0.        , 0.10032906, 0.        ,
#        0.09459597, 0.        , 0.08513638, 0.        , 0.07378486,
#        0.        , 0.06197928, 0.        , 0.05071032, 0.        ,
#        0.04056826, 0.        , 0.03183048, 0.        , 0.02455494,
#        0.        , 0.01866175, 0.        , 0.01399632, 0.        ,
#        0.01037374, 0.        , 0.00760741, 0.        , 0.00552538,
#        0.        , 0.00397827, 0.        , 0.00284162, 0.        ,
#        0.00201497, 0.        , 0.00141924, 0.        , 0.00099347,
#        0.        , 0.00069145, 0.        ])

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
# Місце для Вашого коду

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x1$.

# %%
x1 = np.arange(0, n*5+1)

# %%
# Місце для Вашого коду
plt.stem(nbinom.pmf(x, n, p))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### 1.2 Функція розподілу

# %% [markdown]
# Виведіть значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
# Місце для Вашого коду
nbinom.cdf(x, n, p)
# Out:
# array([0.        , 0.01024   , 0.01024   , 0.04096   , 0.04096   ,
#        0.096256  , 0.096256  , 0.1736704 , 0.1736704 , 0.26656768,
#        0.26656768, 0.36689674, 0.36689674, 0.4672258 , 0.4672258 ,
#        0.56182178, 0.56182178, 0.64695815, 0.64695815, 0.72074301,
#        0.72074301, 0.78272229, 0.78272229, 0.83343262, 0.83343262,
#        0.87400087, 0.87400087, 0.90583135, 0.90583135, 0.93038629,
#        0.93038629, 0.94904805, 0.94904805, 0.96304436, 0.96304436,
#        0.9734181 , 0.9734181 , 0.98102551, 0.98102551, 0.98655089,
#        0.98655089, 0.99052917, 0.99052917, 0.99337079, 0.99337079,
#        0.99538576, 0.99538576, 0.996805  , 0.996805  , 0.99779847,
#        0.99779847, 0.99848993, 0.99848993])

# %% [markdown]
# Зобразіть графічно значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
# Місце для Вашого коду
plt.plot(x, nbinom.cdf(x, n, p), drawstyle='steps-post')

# %% [markdown]
# ### 1.3 Випадкові величини

# %% [markdown]
# Згенеруйте $100$ випадкових величин з від'ємного біноміального розподілу з параметрами $n, p$.

# %%
# Місце для Вашого коду
print("n={}, p={}".format(n, p))
neg_binom = nbinom.rvs(n, p, size=100)
print(*neg_binom)
# Out:
# n=5, p=0.4
# 4 10 4 5 6 10 2 12 6 12 3 6 5 3 3 7 24 7 4 3 5 6 8 3 9 12 6 19 5 8 9 3 14 13 10 8 15 6 4 7 15 8 4 4 6 13 8 20 5 4 3 15 4 1 18 8 5 3 2 10 4 7 7 8 4 8 10 11 10 5 1 1 1 12 12 12 13 5 1 18 5 8 8 8 11 16 4 4 9 7 15 3 1 8 27 4 11 0 13 15

# %% [markdown]
# Виведіть кількість кожного елемента в отриманому випадковому векторі.

# %%
# Місце для Вашого коду
from collections import Counter

counter = Counter()
for v in r_vars:
    counter[v] += 1
    
for v, c in counter.items():
    print("Variable = {0:2}, counter = {1}".format(v, c))
# Out:
# Variable = 15, counter = 3
# Variable = 11, counter = 6
# Variable =  3, counter = 7
# Variable =  8, counter = 10
# Variable =  4, counter = 9
# Variable = 16, counter = 4
# Variable =  5, counter = 13
# Variable =  1, counter = 3
# Variable =  6, counter = 8
# Variable =  9, counter = 4
# Variable = 12, counter = 8
# Variable =  0, counter = 5
# Variable =  7, counter = 4
# Variable =  2, counter = 3
# Variable = 14, counter = 2
# Variable = 13, counter = 3
# Variable = 19, counter = 1
# Variable = 10, counter = 6
# Variable = 18, counter = 1

# %% [markdown]
# Зобразіть графічно кількість кожного елемента в отриманому випадковому векторі.

# %%
# Місце для Вашого коду
items = list(zip(*sorted(counter.items(), key=lambda x: x[0])))
plt.stem(*items);
plt.xlabel('variable');
plt.ylabel('counter');

# %% [markdown]
# ## 2 Гіпергеометричний розподіл

# %% [markdown]
# Більш детальна інформація в [документації](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.hypergeom.html).

# %%
from scipy.stats import hypergeom

# %%
M = 20
n = 7
N = 12

# %% [markdown]
# ### 2.1 Щільність

# %%
x = np.arange(max(0, N-M+n)-0.5, min(n, N)+1, 0.5)

# %% [markdown]
# Виведіть значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
# Місце для Вашого коду
y = hypergeom(M, n, N)

y.pmf(x)
# Out:
# array([0.00000000e+00, 1.03199174e-04, 0.00000000e+00, 4.33436533e-03,
#        0.00000000e+00, 4.76780186e-02, 0.00000000e+00, 1.98658411e-01,
#        0.00000000e+00, 3.57585139e-01, 0.00000000e+00, 2.86068111e-01,
#        0.00000000e+00, 9.53560372e-02, 0.00000000e+00, 1.02167183e-02,
#        0.00000000e+00])

# %% [markdown]
# Зобразіть графічно значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
# Місце для Вашого коду
plt.stem(y.pmf(x));

# %% [markdown]
# Зобразіть графічно значення функції щільності гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x1$.

# %%
x1 = np.arange(max(0, N-M+n), min(n, N)+1)

# %%
# Місце для Вашого коду
plt.stem(y.pmf(x1))
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### 2.2 Функція розподілу

# %% [markdown]
# Виведіть значення функції розподілу гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
# Місце для Вашого коду
y.cdf(x)
# Out:
# array([0.00000000e+00, 1.03199174e-04, 1.03199174e-04, 4.43756450e-03,
#        4.43756450e-03, 5.21155831e-02, 5.21155831e-02, 2.50773994e-01,
#        2.50773994e-01, 6.08359133e-01, 6.08359133e-01, 8.94427245e-01,
#        8.94427245e-01, 9.89783282e-01, 9.89783282e-01, 1.00000000e+00,
#        1.00000000e+00])

# %% [markdown]
# Зобразіть графічно значення функції розподілу гіпергеометричного розподілу з параметрами $M, n, N$ в точках вектора $x$.

# %%
# Місце для Вашого коду
plt.plot(x, y.cdf(x), drawstyle='steps-post')

# %% [markdown]
# ### 2.3 Випадкові величини

# %% [markdown]
# Згенеруйте $100$ випадкових величин з гіпергеометричного розподілу з параметрами $M, n, N$.

# %%
# Місце для Вашого коду
var = y.rvs(size=100)
print(var)
# Out:
# [5 4 6 4 4 4 4 5 5 2 4 4 4 4 4 5 5 5 3 3 4 4 5 4 5 4 6 3 2 5 4 6 4 2 4 5 4
#  3 3 4 3 4 5 4 5 4 5 5 4 6 5 3 4 3 4 3 5 4 3 4 5 5 2 4 3 4 4 3 2 4 6 6 3 3
#  4 4 7 4 5 4 5 5 4 3 4 5 2 5 6 5 4 4 5 5 2 4 3 5 3 5]

# %% [markdown]
# Виведіть кількість кожного елемента в отриманому випадковому векторі.

# %%
# Місце для Вашого коду
from collections import Counter

counter = Counter()
for i in var:
    counter[i] += 1
    
for i, c in counter.items():
    print("Variable = {0:2}, counter = {1}".format(i, c))
# Out:
# Variable =  5, counter = 28
# Variable =  4, counter = 40
# Variable =  6, counter = 7
# Variable =  2, counter = 7
# Variable =  3, counter = 17
# Variable =  7, counter = 1

# %% [markdown]
# Зобразіть графічно кількість кожного елемента в отриманому випадковому векторі.

# %%
# Місце для Вашого коду
items = list(zip(*sorted(counter.items(), key=lambda x: x[0])))
plt.stem(*items)
plt.xlabel('variable')
plt.ylabel('counter')
# Out:
# Text(0, 0.5, 'counter')

# %% [markdown]
# ## 3 Різні параметри

# %% [markdown]
# ### 3.1 Біноміальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин біноміального розподілу з параметрами:
# 1. $n = 15, p = 0.8$
# 2. $n = 15, p = 0.2$
# 3. $n = 20, p = 0.4$
# 4. $n = 20, p = 0.6$
# 5. $n = 7, p = 0.5$
# 6. $n = 25, p = 0.5$
# 7. $n = 100, p = 0.5$

# %%
# Місце для Вашого коду
from scipy.stats import binom

n = [15, 15, 20, 20, 7, 25, 100]
p = [0.8, 0.2, 0.4, 0.6, 0.5, 0.5, 0.5]

plt.figure(figsize=(20, 30))

counter = 0

for j in zip(n, p):
    x = np.arange(0, j[0])

    counter += 1
    plt.subplot(7, 3, counter)
    plt.stem(binom.pmf(x, *j))
    plt.ylabel("n={}, p={}".format(*j))
    plt.title("Probability mass function")
    
    counter += 1
    plt.subplot(7, 3, counter)
    plt.plot(binom.cdf(x, *j), drawstyle="steps-post")
    plt.title("Distribution function")
    
    counter += 1
    y = binom.rvs(*j, size=10000)
    plt.subplot(7, 3, counter)
    plt.hist(y)
    plt.title("Random variables")

# %% [markdown]
# ### 3.2 Геометричний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин геометричного розподілу з параметрами:
# 1. $p = 0.1$
# 2. $p = 0.2$
# 3. $p = 0.3$
# 4. $p = 0.4$
# 5. $p = 0.5$
# 6. $p = 0.6$
# 7. $p = 0.7$
# 8. $p = 0.8$
# 9. $p = 0.9$

# %%
# Місце для Вашого коду
from scipy.stats import geom

p = np.arange(0.1, 1, 0.1)

plt.figure(figsize=(20, 40))

counter = 0

for j in p:
    x = np.arange(0, 100)

    counter += 1
    plt.subplot(9, 3, counter)
    plt.stem(geom.pmf(x, j))
    plt.ylabel("p=%1.1f"%j)
    plt.title("Probability mass function")
    
    counter += 1
    plt.subplot(9, 3, counter)
    plt.plot(geom.cdf(x, j), drawstyle="steps-post")
    plt.title("Distribution function")
    
    counter += 1
    y = geom.rvs(j, size=10000)
    plt.subplot(9, 3, counter)
    plt.hist(y)
    plt.title("Random variables")

# %% [markdown]
# ### 3.3 Розподіл Пуассона

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин розподілу Пуассона з параметрами:
# 1. $\mu = 0.1$
# 2. $\mu = 0.2$
# 3. $\mu = 0.3$
# 4. $\mu = 0.4$
# 5. $\mu = 0.5$
# 6. $\mu = 0.6$
# 7. $\mu = 0.7$
# 8. $\mu = 0.8$
# 9. $\mu = 0.9$

# %%
# Місце для Вашого коду
from scipy.stats import poisson

mu = np.arange(0.1, 1, 0.1)

plt.figure(figsize=(20, 40))

counter = 0

for j in mu:
    x = np.arange(0, 10)

    counter += 1
    plt.subplot(9, 3, counter)
    plt.stem(poisson.pmf(x, j))
    plt.ylabel("mu=%1.1f"%j)
    plt.title("Probability mass function")
    
    counter += 1
    plt.subplot(9, 3, counter)
    plt.plot(poisson.cdf(x, j), drawstyle="steps-post")
    plt.title("Distribution function")
    
    counter += 1
    y = poisson.rvs(j, size=10000)
    plt.subplot(9, 3, counter)
    plt.hist(y)
    plt.title("Random variables")

# %% [markdown]
# ### 3.4 Від'ємний біноміальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин від'ємного біноміального розподілу з параметрами:
# 1. $n = 15, p = 0.8$
# 2. $n = 15, p = 0.2$
# 3. $n = 20, p = 0.4$
# 4. $n = 20, p = 0.6$
# 5. $n = 7, p = 0.5$
# 6. $n = 25, p = 0.5$
# 7. $n = 100, p = 0.5$

# %%
# Місце для Вашого коду
from scipy.stats import nbinom

n = [15, 15, 20, 20, 7, 25, 100]
p = [0.8, 0.2, 0.4, 0.6, 0.5, 0.5, 0.5]

plt.figure(figsize=(20, 40))

counter = 0

for j in zip(n, p):
    x = np.arange(0, 100)

    counter += 1
    plt.subplot(7, 3, counter)
    plt.stem(nbinom.pmf(x, *j))
    plt.ylabel("n={}, p={}".format(*j))
    plt.title("Probability mass function")
    
    counter += 1
    plt.subplot(7, 3, counter)
    plt.plot(nbinom.cdf(x, *j), drawstyle="steps-post")
    plt.title("Distribution function")
    
    counter += 1
    y = nbinom.rvs(*j, size=10000)
    plt.subplot(7, 3, counter)
    plt.hist(y)
    plt.title("Random variables")

# %% [markdown]
# ### 3.5 Гіпергеометричний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин гіпергеометричного розподілу з параметрами:
# 1. $M = 10, n = 3, N = 7$
# 2. $M = 50, n = 10, N = 5$
# 3. $M = 50, n = 10, N = 10$
# 4. $M = 50, n = 10, N = 20$
# 5. $M = 50, n = 10, N = 30$
# 6. $M = 50, n = 10, N = 40$
# 7. $M = 50, n = 10, N = 50$
# 8. $M = 50, n = 5, N = 25$
# 9. $M = 50, n = 15, N = 25$
# 10. $M = 50, n = 25, N = 25$
# 11. $M = 50, n = 35, N = 25$
# 12. $M = 50, n = 45, N = 25$

# %%
# Місце для Вашого коду
from scipy.stats import hypergeom

M = [10] + [50 for i in range(11)]
n = [3] + [10 for i in range(6)] + [5, 15, 25, 35, 45]
N = [7, 5, 10, 20, 30, 40, 50] + [25 for i in range(5)]

plt.figure(figsize=(20, 50))

counter = 0

for j in zip(M, n, N):
    x = np.arange(0, 30)

    counter += 1
    plt.subplot(12, 3, counter)
    plt.stem(hypergeom.pmf(x, *j))
    plt.ylabel("M={}, n={}, N={}".format(*j))
    plt.title("Probability mass function")
    
    counter += 1
    plt.subplot(12, 3, counter)
    plt.plot(hypergeom.cdf(x, *j), drawstyle="steps-post")
    plt.title("Distribution function")
    
    counter += 1
    rv = hypergeom.rvs(*j, size=10000)
    plt.subplot(12, 3, counter)
    plt.hist(rv)
    plt.title("Random variables")

# %% [markdown]
# ## 4 Апроксимація біноміального розподілу розподілом Пуассона

# %% [markdown]
# Покажіть схожість біноміального розподілу та розподілу Пуассона (їх функцій щільності) з відповідними параметрами.
# Наприклад:
# - $n = 100, p = 0.05$
# - $n = 100, p = 0.1$
# - $n = 100, p = 0.15$
# - $n = 100, p = 0.2$
# - $n = 100, p = 0.35$
# - $n = 100, p = 0.5$
# - $n = 100, p = 0.75$

# %%
# Місце для Вашого коду
from scipy.stats import binom, poisson

N = [100 for i in range(7)]
p = [0.05, 0.1, 0.15, 0.2, 0.35, 0.5, 0.75]

plt.figure(figsize=(20, 50))

counter = 0

for j in zip(N, p):
    x = np.arange(0, 100)
     
    counter += 1
    plt.subplot(7, 2, counter)
    plt.stem(binom.pmf(x, *j))
    plt.ylabel("n={}, p={}".format(*j))
    plt.title("Probability mass function (Binomial distribution)")
    
    counter += 1
    plt.subplot(7, 2, counter)
    plt.stem(poisson.pmf(x, j[0]*j[1]))
    plt.ylabel("mu={}".format(j[0]*j[1]))
    plt.title("Probability mass function (Poisson distribution)")
